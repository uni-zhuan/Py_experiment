# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
import matplotlib.pyplot as plt
data=pd.read_csv("F:\Python\data\High-speed+rail.csv",index_col="Country")
data["Operation"].plot(kind="bar",title="Operation Mileage",rot=45)
# plt.xticks(range(0,11),("A","B","C","D","E","F","G","H","I","J","K"))
plt.annotate("Longest",xytext=(1,20000),xy=(0.05,20000),arrowprops=dict(arrowstyle="->"))
plt.show()

# %%
data.plot(kind="bar",title="堆叠图",stacked=True)
plt.show()

# %%
data2=data["Operation"]
data2.plot(kind="pie",explode=[0.1,0,0,0,0,0],autopct="%1.1f%%",subplots=True)
plt.show()
