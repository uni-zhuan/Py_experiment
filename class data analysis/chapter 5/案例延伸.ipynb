# %%
import numpy as np 
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt

data=pd.read_csv("F:\Python\data\Advertising.csv",index_col=0)
datahalf=data[0:100]
datahalf
# Out:
#         TV  Weibo  WeChat  Sales
# 1    230.1   37.8    69.2   22.1
# 2     44.5   39.3    45.1   10.4
# 3     17.2   45.9    69.3    9.3
# 4    151.5   41.3    58.5   18.5
# 5    180.8   10.8    58.4   12.9
# 6      8.7   48.9    75.0    7.2
# 7     57.5   32.8    23.5   11.8
# 8    120.2   19.6    11.6   13.2
# 9      8.6    2.1     1.0    4.8
# 10   199.8    2.6    21.2   10.6
# 11    66.1    5.8    24.2    8.6
# 12   214.7   24.0     4.0   17.4
# 13    23.8   35.1    65.9    9.2
# 14    97.5    7.6     7.2    9.7
# 15   204.1   32.9    46.0   19.0
# 16   195.4   47.7    52.9   22.4
# 17    67.8   36.6   114.0   12.5
# 18   281.4   39.6    55.8   24.4
# 19    69.2   20.5    18.3   11.3
# 20   147.3   23.9    19.1   14.6
# 21   218.4   27.7    53.4   18.0
# 22   237.4    5.1    23.5   12.5
# 23    13.2   15.9    49.6    5.6
# 24   228.3   16.9    26.2   15.5
# 25    62.3   12.6    18.3    9.7
# 26   262.9    3.5    19.5   12.0
# 27   142.9   29.3    12.6   15.0
# 28   240.1   16.7    22.9   15.9
# 29   248.8   27.1    22.9   18.9
# 30    70.6   16.0    40.8   10.5
# ..     ...    ...     ...    ...
# 71   199.1   30.6    38.7   18.3
# 72   109.8   14.3    31.7   12.4
# 73    26.8   33.0    19.3    8.8
# 74   129.4    5.7    31.3   11.0
# 75   213.4   24.6    13.1   17.0
# 76    16.9   43.7    89.4    8.7
# 77    27.5    1.6    20.7    6.9
# 78   120.5   28.5    14.2   14.2
# 79     5.4   29.9     9.4    5.3
# 80   116.0    7.7    23.1   11.0
# 81    76.4   26.7    22.3   11.8
# 82   239.8    4.1    36.9   12.3
# 83    75.3   20.3    32.5   11.3
# 84    68.4   44.5    35.6   13.6
# 85   213.5   43.0    33.8   21.7
# 86   193.2   18.4    65.7   15.2
# 87    76.3   27.5    16.0   12.0
# 88   110.7   40.6    63.2   16.0
# 89    88.3   25.5    73.4   12.9
# 90   109.8   47.8    51.4   16.7
# 91   134.3    4.9     9.3   11.2
# 92    28.6    1.5    33.0    7.3
# 93   217.7   33.5    59.0   19.4
# 94   250.9   36.5    72.3   22.2
# 95   107.4   14.0    10.9   11.5
# 96   163.3   31.6    52.9   16.9
# 97   197.6    3.5     5.9   11.7
# 98   184.9   21.0    22.0   15.5
# 99   289.7   42.3    51.2   25.4
# 100  135.2   41.7    45.9   17.2
#
# [100 rows x 4 columns]

# %%
#得到线性模型
from sklearn.linear_model import LinearRegression
linreg=LinearRegression()
x=datahalf.iloc[:,0:3].values.astype(float)
y=datahalf.iloc[:,3].values.astype(float)
linreg.fit(x,y)
print(linreg.intercept_,linreg.coef_)
# Out:
# 3.34978539235 [ 0.04551295  0.19208846 -0.01066575]

# %%
#将数据集拆分为训练集和测试集，在测试集上查看分类效果
from sklearn import model_selection
X_train,X_test,y_train,y_test=model_selection.train_test_split(x,y,test_size=0.3,random_state=1)
linregTr=LinearRegression()
linregTr.fit(X_train,y_train)
print(linregTr.intercept_,linregTr.coef_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-dfe5a6aaa4fc> in <module>()
#       1 #将数据集拆分为训练集和测试集，在测试集上查看分类效果
#       2 from sklearn import model_selection
# ----> 3 X_train,X_test,y_train,y_test=model_selection.train_test_split(X,y,test_size=0.3,random_state=1)
#       4 linregTr=LinearRegression()
#       5 linregTr.fit(X_train,y_train)
#
# NameError: name 'X' is not defined

# %%
from sklearn import metrics
predict_score=linregTr.score(X_test,y_test)
print("decision coeficient is:{:.4f}".format(predict_score))
y_test_pred1=linreg.predict(X_test)
test_err1=metrics.mean_squared_error(y_test,y_test_pred1)
print("error is:{:.4f}".format(test_err1))

# %%
from sklearn.linear_model importLinearRegression
X_half=data.iloc[0:100,0:3].value.astype(float)
y_half=data.iloc[0:100,3].value.astype(float)
linreg_half=linearRegression()
linear_half.fit(X_half,y_half)
print(linreg_half.intercept_,linreg_half.coef_)
