# %%
import pandas as pd
import numpy as np
from pandas import Series,DataFrame
colnames=["flymiles","videogame","icecream","type"]
data=pd.read_csv("F:\Python\data\datingTestSet.csv",skiprows=2,header=None,names=colnames)
data
# Out:
#      flymiles  videogame  icecream        type
# 0     40920.0   8.326976  0.953952  largeDoses
# 1     14488.0   7.153469  1.673904  smallDoses
# 2     26052.0   1.441871  0.805124   didntLike
# 3     75136.0  13.147394  0.428964   didntLike
# 4     38344.0   1.669788  0.134296   didntLike
# 5     72993.0  10.141740  1.032955   didntLike
# 6     35948.0   6.830792  1.213192  largeDoses
# 7     42666.0  13.276369  0.543880  largeDoses
# 8     67497.0   8.631577  0.749278   didntLike
# 9     35483.0  12.273169  1.508053  largeDoses
# 10    50242.0   3.723498  0.831917   didntLike
# 11    63275.0   8.385879  1.669485   didntLike
# 12     5569.0   4.875435  0.728658  smallDoses
# 13    51052.0   4.680098  0.625224   didntLike
# 14    77372.0  15.299570  0.331351   didntLike
# 15    43673.0   1.889461  0.191283   didntLike
# 16    61364.0   7.516754  1.269164   didntLike
# 17    69673.0  14.239195  0.261333   didntLike
# 18    15669.0        NaN  1.250185  smallDoses
# ...

# %%
data[:5]
# Out:
#    flymiles  videogame  icecream        type
# 0   40920.0   8.326976  0.953952  largeDoses
# 1   14488.0   7.153469  1.673904  smallDoses
# 2   26052.0   1.441871  0.805124   didntLike
# 3   75136.0  13.147394  0.428964   didntLike
# 4   38344.0   1.669788  0.134296   didntLike

# %%
mask=data["type"]=="largeDoses"
data.loc[mask]
# Out:
#      flymiles  videogame  icecream        type
# 0     40920.0   8.326976  0.953952  largeDoses
# 6     35948.0   6.830792  1.213192  largeDoses
# 7     42666.0  13.276369  0.543880  largeDoses
# 9     35483.0  12.273169  1.508053  largeDoses
# 19    28488.0  10.528555  1.304844  largeDoses
# 23    28782.0   6.593803  0.187108  largeDoses
# 25    36788.0  12.458258  0.649617  largeDoses
# 27    28567.0   9.968648  0.731232  largeDoses
# 30    36661.0  11.865402  0.882810  largeDoses
# 32    15360.0   8.545204  1.340429  largeDoses
# 38    14851.0  14.305636  0.632317  largeDoses
# 39    33553.0  12.591889  0.686581  largeDoses
# 42    27738.0   8.533823  0.205324  largeDoses
# 43    29290.0   9.829528  0.238620  largeDoses
# 44    42330.0  11.492186  0.263499  largeDoses
# 52    41539.0  10.393591  1.663724  largeDoses
# 57    18983.0  10.448091  0.267652  largeDoses
# 66     9744.0  11.470364  0.760461  largeDoses
# 68    39336.0  10.054373  1.138351  largeDoses
# ...

# %%
mask=data["videogame"]>10
data.loc[mask]=10
data
# Out:
#      flymiles  videogame   icecream        type
# 0     40920.0   8.326976   0.953952  largeDoses
# 1     14488.0   7.153469   1.673904  smallDoses
# 2     26052.0   1.441871   0.805124   didntLike
# 3        10.0  10.000000  10.000000          10
# 4     38344.0   1.669788   0.134296   didntLike
# 5        10.0  10.000000  10.000000          10
# 6     35948.0   6.830792   1.213192  largeDoses
# 7        10.0  10.000000  10.000000          10
# 8     67497.0   8.631577   0.749278   didntLike
# 9        10.0  10.000000  10.000000          10
# 10    50242.0   3.723498   0.831917   didntLike
# 11    63275.0   8.385879   1.669485   didntLike
# 12     5569.0   4.875435   0.728658  smallDoses
# 13    51052.0   4.680098   0.625224   didntLike
# 14       10.0  10.000000  10.000000          10
# 15    43673.0   1.889461   0.191283   didntLike
# 16    61364.0   7.516754   1.269164   didntLike
# 17       10.0  10.000000  10.000000          10
# 18    15669.0        NaN   1.250185  smallDoses
# ...
